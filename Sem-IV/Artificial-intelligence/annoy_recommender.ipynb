# %% [markdown]
# ### Recommendation engine using ANNOY

# %%
from ast import literal_eval
import pandas as pd
import json

# %%
class_labels = pd.read_csv("class_labels_indices.csv")
music_dict = dict(zip(class_labels.index, class_labels.display_name))

# %%
with open("music_set.json", "r") as file:
    file_read = json.loads(file.read())
    music_dataset = literal_eval(file_read)

# %%
len(music_dataset)
# Out:
# 5883

# %%
from annoy import AnnoyIndex

audio_dim = 1280
annoy_index = AnnoyIndex(audio_dim, "angular")
for index in range(len(music_dataset[:1000])):
    vector = music_dataset[index]["data"]
    annoy_index.add_item(index, vector)

annoy_index.build(50)
annoy_index.save("nearest_neightbor_graph.ann")
# Out:
# True

# %%
annoy_index = AnnoyIndex(audio_dim, "angular")
annoy_index.load("nearest_neightbor_graph.ann")
# Out:
# True

# %%
nns_index = annoy_index.get_nns_by_item(100,10)

# %%
for index in nns_index:
    sample = music_dataset[index]
    music_labels = [music_dict[idx] for idx in sample["label"]]
    print([index, music_labels, sample["video_id"], sample["start_time"], sample["end_time"]])
# Out:
# [100, ['Speech', 'Music', 'Didgeridoo'], [b'c5D90N1qrD0'], [30.0], [40.0]]
# [902, ['Music', 'Didgeridoo'], [b'56_BCN7x6F8'], [30.0], [40.0]]
# [76, ['Music', 'Didgeridoo'], [b'VeXcCHo5iMI'], [30.0], [40.0]]
# [880, ['Music', 'Didgeridoo'], [b'NPXZIqxKvXA'], [30.0], [40.0]]
# [660, ['Music', 'Didgeridoo'], [b'jKjj66pRXZA'], [20.0], [30.0]]
# [228, ['Music', 'Didgeridoo'], [b'R4jlQEweREY'], [30.0], [40.0]]
# [684, ['Music', 'Didgeridoo'], [b'-Vo4CAMX26U'], [30.0], [40.0]]
# [69, ['Music', 'Didgeridoo'], [b'BsnjK6DypAg'], [30.0], [40.0]]
# [157, ['Music', 'Boing'], [b'OYjo0qCQFpw'], [510.0], [520.0]]
# [425, ['Music', 'Musical instrument', 'Didgeridoo'], [b'VgwsGjRk61M'], [20.0], [30.0]]

# %%
for index in range(len(music_dataset[:1000])):
    sample = music_dataset[index]
    music_labels = [music_dict[idx] for idx in sample["label"]]
    print(index, music_labels)
# Out:
# 0 ['Speech', 'Male singing', 'Female singing', 'Music']
# 1 ['Speech', 'Music', 'Splash, splatter', 'Slosh']
# 2 ['Music', 'Theme music', 'Soundtrack music']
# 3 ['Music', 'Hip hop music', 'Boom']
# 4 ['Speech', 'Music', 'Bouncing']
# 5 ['Music', 'Banjo', 'Rock and roll', 'Country', 'Bluegrass']
# 6 ['Music', 'Song', 'Zing']
# 7 ['Music', 'Folk music', 'Song']
# 8 ['Music', 'Clatter']
# 9 ['Speech', 'Crow', 'Caw', 'Music']
# 10 ['Music', 'Electric guitar', 'Echo']
# 11 ['Singing', 'Music', 'Middle Eastern music', 'Carnatic music', 'Music of Bollywood', 'Song']
# 12 ['Music', 'Music of Latin America', 'Flamenco']
# 13 ['Music', 'Tambourine']
# 14 ['Speech', 'Music', 'Beatboxing']
# 15 ['Music', 'Musical instrument', 'Music of Africa', 'Traditional music']
# 16 ['Yodeling', 'Music']
# 17 ['Singing', 'Mouse', 'Music', 'Song']
# 18 ['Speech', 'Music', 'Ice cream truck, ice cream van']
# 19 ['Music', 'Electronic music', 'Dubstep']
# 20 ['Bellow', 'Singing', 'Music', 'Christian music', 'Gospel music', 'Song']
# 21 ['Speech', 'Animal', 'Horse', 'Neigh, whinny', 'Music']
# 22 ['Music', 'Heavy metal', 'Progressive rock', 'Background music', 'Theme music']
# 23 ['Music', 'Rock music', 'Heavy metal', 'Progressive rock', 'Psychedelic rock']
# 24 ['Music', 'Synthesizer']
# 25 ['Music', 'Reggae', 'Music of Africa', 'Afrobeat']
# 26 ['Music', 'Afrobeat', 'Music of Asia', 'Dance music']
# 27 ['Music', 'Music for children', 'Happy music']
# 28 ['Speech', 'Music', 'Boing']
# 29 ['Music', 'Musical instrument', 'Wind instrument, woodwind instrument', 'Flute', 'Classical music', 'New-age music', 'Background music']
# 30 ['Applause', 'Music']
# 31 ['Music', 'Exciting music']
# 32 ['Music', 'Classical music', 'Opera', 'Song']
# 33 ['Heart murmur', 'Music']
# 34 ['Music', 'Techno', 'Dubstep', 'Electronic dance music', 'Dance music', 'Rumble']
# 35 ['Synthetic singing', 'Music']
# 36 ['Music', 'Heavy metal', 'Punk rock', 'Grunge', 'Progressive rock']
# 37 ['Music', 'Fireworks']
# 38 ['Speech', 'Music', 'Maraca']
# 39 ['Music', 'Scary music']
# 40 ['Music', 'Musical instrument', 'Synthesizer', 'Sampler', 'Drum machine', 'House music', 'Techno', 'Dubstep', 'Electronic dance music', 'Trance music', 'Afrobeat']
# 41 ['Speech', 'Music', 'Doorbell']
# 42 ['Music', 'Rattle (instrument)']
# 43 ['Speech', 'Music', 'Ice cream truck, ice cream van', 'Clock', 'Tick-tock']
# 44 ['Music', 'Toot', 'Outside, urban or manmade']
# 45 ['Speech', 'Stomach rumble', 'Music']
# 46 ['Speech', 'Music', 'Reggae']
# 47 ['Speech', 'Music', 'Music for children', 'Plop']
# 48 ['Speech', 'Music', 'Drum machine', 'Single-lens reflex camera']
# 49 ['Animal', 'Horse', 'Clip-clop', 'Music']
# 50 ['Music', 'Scratch']
# 51 ['Music', 'Techno', 'Drum and bass', 'Electronica', 'Air horn, truck horn']
# 52 ['Speech', 'Music', 'Music for children', 'Electric toothbrush', 'Inside, small room']
# 53 ['Choir', 'Music', 'A capella']
# 54 ['Whale vocalization', 'Music']
# 55 ['Music', 'Ukulele', 'Music of Asia']
# 56 ['Music', 'Rock and roll', 'Roll']
# 57 ['Music', 'Exciting music', 'Pulse']
# 58 ['Speech', 'Music', 'Rock and roll', 'Roll']
# 59 ['Music', 'Music of Latin America', 'Flamenco']
# 60 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Chorus effect']
# 61 ['Music', 'Sad music']
# 62 ['Music', 'Techno', 'Drum and bass', 'Electronic dance music', 'Dance music']
# 63 ['Music', 'Scrape']
# 64 ['Shout', 'Music']
# 65 ['Synthetic singing', 'Music', 'Theme music']
# 66 ['Music', 'Funk', 'Music of Africa', 'Afrobeat']
# 67 ['Music', 'Christmas music']
# 68 ['Whistling', 'Keyboard (musical)', 'Piano']
# 69 ['Music', 'Didgeridoo']
# 70 ['Male speech, man speaking', 'Singing', 'Choir', 'Music', 'Gospel music']
# 71 ['Music', 'Salsa music']
# 72 ['Music', 'Musical instrument', 'Sitar', 'Tabla', 'Bowed string instrument', 'Music of Asia']
# 73 ['Music', 'Heavy metal', 'Punk rock', 'Progressive rock', 'Distortion']
# 74 ['Music', 'Plucked string instrument', 'Guitar', 'Acoustic guitar', 'Strum', 'Mandolin']
# 75 ['Music', 'A capella', 'Sad music', 'Scary music']
# 76 ['Music', 'Didgeridoo']
# 77 ['Music', 'Wedding music']
# 78 ['Music', 'Ambient music']
# 79 ['Music', 'Jazz', 'Electronic music']
# 80 ['Speech', 'Music', 'Telephone bell ringing']
# 81 ['Music', 'Rattle (instrument)']
# 82 ['Speech', 'Music', 'Fusillade']
# 83 ['Music', 'Pop music', 'Rock and roll', 'Music of Asia']
# 84 ['Speech', 'Music', 'Tambourine']
# 85 ['Speech', 'Child speech, kid speaking', 'Music', 'Toothbrush']
# 86 ['Music', 'Maraca', 'Salsa music', 'Song']
# 87 ['Music', 'Video game music', 'Funny music']
# 88 ['Music', 'Synthesizer', 'Sampler', 'Drum machine', 'Scratching (performance technique)', 'Scratch']
# 89 ['Music', 'Vibraphone', 'Inside, small room']
# 90 ['Music', 'Maraca', 'Music of Latin America']
# 91 ['Music', 'House music', 'Electronica', 'Song']
# 92 ['Music', 'Gurgling']
# 93 ['Speech', 'Heart murmur', 'Music']
# 94 ['Animal', 'Duck', 'Quack', 'Music']
# 95 ['Music', 'Carnatic music']
# 96 ['Singing', 'Music', 'Song', 'Wedding music']
# 97 ['Singing', 'Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Banjo', 'Mandolin']
# 98 ['Music', 'Lullaby']
# 99 ['Speech', 'Music', 'Theremin', 'Inside, large room or hall']
# 100 ['Speech', 'Music', 'Didgeridoo']
# 101 ['Speech', 'Run', 'Music']
# 102 ['Speech', 'Music', 'Crack']
# 103 ['Music', 'Hip hop music', 'Drip']
# 104 ['Speech', 'Music', 'Harmonic']
# 105 ['Music', 'Angry music']
# 106 ['Speech', 'Music', 'Explosion']
# 107 ['Speech', 'Music', 'Tambourine']
# 108 ['Chant', 'Mantra', 'Music', 'New-age music']
# 109 ['Rapping', 'Music', 'Hip hop music']
# 110 ['Singing', 'Music', 'Opera']
# 111 ['Speech', 'Music', 'Shuffling cards']
# 112 ['Rapping', 'Music', 'Hip hop music', 'Rhythm and blues', 'Zing']
# 113 ['Music', 'Guitar', 'Music of Latin America', 'Salsa music', 'Music of Africa', 'Dance music']
# 114 ['Music', 'Squeak']
# 115 ['Music', 'Reggae', 'Music of Africa', 'Afrobeat']
# 116 ['Speech', 'Music', 'Trickle, dribble']
# 117 ['Speech', 'Music', 'Spray']
# 118 ['Music', 'Music for children', 'Boing']
# 119 ['Speech', 'Whimper (dog)', 'Music']
# 120 ['Singing', 'Music', 'Happy music']
# 121 ['Music', 'Guitar', 'Electronic tuner']
# 122 ['Speech', 'Music', 'Scary music']
# 123 ['Music', 'Sewing machine']
# 124 ['Speech', 'Shout', 'Music', 'Inside, large room or hall']
# 125 ['Chant', 'Music']
# 126 ['Music', 'Happy music']
# 127 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Tapping (guitar technique)', 'Electronic tuner']
# 128 ['Music', 'Carnatic music']
# 129 ['Music', 'Air horn, truck horn']
# 130 ['Speech', 'Singing', 'Music', 'Funny music']
# 131 ['Music', 'Independent music', 'Tender music']
# 132 ['Singing', 'Yodeling', 'Music', 'Acoustic guitar', 'Steel guitar, slide guitar', 'Country']
# 133 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Bass guitar', 'Tapping (guitar technique)', 'Effects unit']
# 134 ['Speech', 'Chatter', 'Music']
# 135 ['Music', 'Scratching (performance technique)', 'Scratch']
# 136 ['Singing', 'Yodeling', 'Music', 'Music of Latin America']
# 137 ['Music', 'Guitar', 'Mandolin', 'Flamenco']
# 138 ['Speech', 'Music', 'Air horn, truck horn', 'Inside, large room or hall']
# 139 ['Speech', 'Music', 'Music of Asia']
# 140 ['Grunt', 'Music']
# 141 ['Speech', 'Music', 'Vibraphone', 'Inside, small room']
# 142 ['Bleat', 'Music']
# 143 ['Music', 'Angry music']
# 144 ['Speech', 'Breathing', 'Music']
# 145 ['Rapping', 'Music', 'Ska', 'Independent music']
# 146 ['Music', 'Rock and roll', 'Whir']
# 147 ['Shuffle', 'Music']
# 148 ['Clapping', 'Music']
# 149 ['Music', 'Sad music']
# 150 ['Music', 'Electronica', 'Ambient music', 'Background music']
# 151 ['Music', 'Pop music', 'Heavy metal', 'Progressive rock', 'Independent music', 'Tick-tock']
# 152 ['Rapping', 'Music', 'Hip hop music', 'Reggae', 'Funny music']
# 153 ['Animal', 'Wild animals', 'Music', 'Background music']
# 154 ['Music', 'Electronic music', 'Techno']
# 155 ['Speech', 'Hubbub, speech noise, speech babble', 'Music']
# 156 ['Speech', 'Child speech, kid speaking', 'Children playing', 'Music', 'Inside, small room']
# 157 ['Music', 'Boing']
# 158 ['Animal', 'Horse', 'Music']
# 159 ['Speech', 'Music', 'Electric shaver, electric razor', 'Inside, small room']
# 160 ['Music', 'Swing music', 'Blues']
# 161 ['Music', 'Christmas music']
# 162 ['Music', 'Jazz']
# 163 ['Choir', 'Music', 'Opera', 'Gospel music']
# 164 ['Music', 'Fireworks', 'Firecracker', 'Outside, urban or manmade']
# 165 ['Music', 'Glockenspiel', 'Ding-dong']
# 166 ['Singing', 'Snort', 'Music', 'Song']
# 167 ['Music', 'Ambient music', 'New-age music']
# 168 ['Speech', 'Narration, monologue', 'Music', 'Middle Eastern music']
# 169 ['Music', 'Steelpan']
# 170 ['Music', 'Christmas music']
# 171 ['Speech', 'Music', 'Boom']
# 172 ['Music', 'Maraca']
# 173 ['Speech', 'Music', 'Electric toothbrush', 'Inside, large room or hall']
# 174 ['Chant', 'Music', 'Christian music', 'Gospel music', 'Song']
# 175 ['Music', 'Funny music']
# 176 ['Bellow', 'Music', 'Inside, large room or hall']
# 177 ['Speech', 'Female singing', 'Child singing', 'Music']
# 178 ['Music', 'Timpani', 'Folk music']
# 179 ['Musical instrument', 'Plucked string instrument', 'Guitar', 'Echo', 'Distortion']
# 180 ['Music', 'Music of Bollywood']
# 181 ['Animal', 'Domestic animals, pets', 'Dog', 'Howl', 'Canidae, dogs, wolves', 'Music']
# 182 ['Music', 'Dubstep', 'Burst, pop']
# 183 ['Music', 'Boom']
# 184 ['Music', 'Vocal music', 'A capella']
# 185 ['Music', 'Music for children', 'Clock']
# 186 ['Music', 'Harmonic']
# 187 ['Music', 'Musical instrument', 'Accordion', 'Traditional music']
# 188 ['Music', 'Jazz']
# 189 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Bass guitar', 'Tapping (guitar technique)', 'Heavy metal', 'Distortion']
# 190 ['Speech', 'Music', 'Musical instrument', 'Guitar', 'Electric guitar', 'Bass guitar', 'Effects unit', 'Distortion']
# 191 ['Speech', 'Purr', 'Music']
# 192 ['Music', 'Shatter']
# 193 ['Music', 'Musical instrument', 'Guitar', 'Pop music', 'Christian music', 'Song']
# 194 ['Music', 'Classical music', 'Wedding music']
# 195 ['Music', 'Ringtone']
# 196 ['Music', 'Burst, pop']
# 197 ['Speech', 'Music', 'Inside, public space']
# 198 ['Music', 'Shatter']
# 199 ['Speech', 'Run', 'Music']
# 200 ['Speech', 'Music', 'Foghorn']
# 201 ['Choir', 'Music', 'Christian music', 'Gospel music', 'Christmas music']
# 202 ['Music', 'New-age music', 'Background music']
# 203 ['Music', 'Heavy metal', 'Grunge', 'Exciting music']
# 204 ['Singing', 'Groan', 'Music']
# 205 ['Music', 'Steel guitar, slide guitar', 'Blues']
# 206 ['Music', 'Ice cream truck, ice cream van', 'Outside, urban or manmade']
# 207 ['Music', 'Video game music', 'Cacophony']
# 208 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Tapping (guitar technique)', 'Distortion']
# 209 ['Music', 'Musical instrument', 'Plucked string instrument', 'Sitar', 'Country']
# 210 ['Music', 'Dubstep', 'Drum and bass', 'Electronica', 'Electronic dance music']
# 211 ['Singing', 'Music', 'Country', 'Christian music', 'Song']
# 212 ['Speech', 'Music', 'Slosh', 'Inside, small room', 'Outside, urban or manmade']
# 213 ['Music', 'Tender music']
# 214 ['Music', 'Musical instrument', 'Guitar', 'Electric guitar', 'Effects unit', 'Echo', 'Distortion']
# 215 ['Music', 'Traditional music']
# 216 ['Speech', 'Music', 'Tambourine']
# 217 ['Music', 'Middle Eastern music', 'Music of Bollywood']
# 218 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Bass guitar', 'Effects unit', 'Silence', 'Reverberation']
# 219 ['Speech', 'Child speech, kid speaking', 'Music', 'Splash, splatter']
# 220 ['Music', 'Video game music', 'Tender music', 'Cacophony']
# 221 ['Speech', 'Music', 'Background music', 'Theme music', 'Flap']
# 222 ['Music', 'Folk music', 'Music of Asia']
# 223 ['Music', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Steel guitar, slide guitar', 'Tapping (guitar technique)', 'Strum', 'Effects unit', 'Distortion']
# 224 ['Music', 'Rhythm and blues', 'Zing']
# 225 ['Rattle', 'Music', 'Rock music']
# 226 ['Music', 'Sonar']
# 227 ['Speech', 'Speech synthesizer', 'Music', 'Beep, bleep']
# 228 ['Music', 'Didgeridoo']
# 229 ['Music', 'Electric guitar', 'Blues', 'Effects unit', 'Echo', 'Distortion']
# 230 ['Roar', 'Music']
# 231 ['Music', 'Reggae', 'Jingle (music)']
# 232 ['Speech', 'Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Acoustic guitar', 'Steel guitar, slide guitar', 'Strum']
# 233 ['Speech', 'Yodeling', 'Music', 'Inside, public space']
# 234 ['Choir', 'Music', 'A capella', 'Gospel music']
# 235 ['Music', 'Punk rock', 'Grunge']
# 236 ['Music', 'Exciting music']
# 237 ['Applause', 'Music']
# 238 ['Music', 'Folk music']
# 239 ['Music', 'Skateboard']
# 240 ['Choir', 'Music', 'A capella', 'Gospel music']
# 241 ['Speech', 'Music', 'Musical instrument', 'Guitar', 'Strum', 'Bluegrass']
# 242 ['Music', 'Timpani']
# 243 ['Speech', 'Music', 'Ding-dong']
# 244 ['Speech', 'Music', 'Thunk']
# 245 ['Music', 'Basketball bounce', 'Outside, urban or manmade']
# 246 ['Music', 'Musical instrument', 'Violin, fiddle', 'Scratching (performance technique)', 'Scratch']
# 247 ['Musical instrument', 'Plucked string instrument', 'Guitar', 'Steel guitar, slide guitar', 'Tapping (guitar technique)', 'Echo']
# 248 ['Music', 'Electronic music', 'House music', 'Techno']
# 249 ['Child singing', 'Music']
# 250 ['Speech', 'Music', 'Scary music']
# 251 ['Music', 'Cacophony']
# 252 ['Music', 'Hip hop music', 'Disco', 'Techno', 'Dubstep', 'Trance music', 'Dance music']
# 253 ['Speech', 'Caw', 'Music']
# 254 ['Music', 'Ding-dong']
# 255 ['Music', 'Banjo', 'Bluegrass']
# 256 ['Music', 'Music of Asia']
# 257 ['Music', 'Electronic music', 'Techno']
# 258 ['Duck', 'Quack', 'Music']
# 259 ['Music', 'Soundtrack music', 'Pulse']
# 260 ['Music', 'Middle Eastern music']
# 261 ['Music', 'Ambient music']
# 262 ['Music', 'Synthesizer', 'Sampler']
# 263 ['Keyboard (musical)', 'Piano', 'Electric piano', 'Organ', 'Hammond organ']
# 264 ['Musical instrument', 'Plucked string instrument', 'Guitar', 'Flamenco']
# 265 ['Speech', 'Music', 'Explosion']
# 266 ['Bellow', 'Music']
# 267 ['Music', 'Dubstep', 'Drum and bass', 'Electronica', 'Electronic dance music', 'Dance music']
# 268 ['Speech', 'Stomach rumble', 'Music']
# 269 ['Singing', 'Yodeling', 'Music', 'Guitar']
# 270 ['Speech', 'Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Strum', 'Electronic tuner']
# 271 ['Music', 'Shatter', 'Inside, small room']
# 272 ['Shout', 'Singing', 'Music', 'Musical instrument', 'Guitar', 'Rock music']
# 273 ['Music', 'Echo']
# 274 ['Speech', 'Music', 'Electric guitar', 'Tapping (guitar technique)']
# 275 ['Music', 'Music of Bollywood', 'Soundtrack music']
# 276 ['Synthetic singing', 'Bleat', 'Music']
# 277 ['Music', 'Synthesizer', 'Effects unit', 'Noise']
# 278 ['Speech', 'Music', 'Beep, bleep']
# 279 ['Speech', 'Music', 'Sidetone']
# 280 ['Music', 'Progressive rock', 'Independent music']
# 281 ['Speech', 'Children playing', 'Music', 'Outside, urban or manmade']
# 282 ['Speech', 'Music', 'Electronic tuner', 'Inside, small room']
# 283 ['Music', 'Rock music', 'Progressive rock', 'Christian music', 'Song', 'Christmas music']
# 284 ['Keyboard (musical)', 'Piano', 'Bowed string instrument', 'Cello', 'Double bass']
# 285 ['Music', 'Tender music']
# 286 ['Music', 'Piano', 'Inside, small room', 'Reverberation']
# 287 ['Rock music', 'Punk rock', 'Progressive rock', 'Ska']
# 288 ['Music', 'A capella', 'Music of Africa', 'Liquid', 'Drip']
# 289 ['Singing', 'Music', 'Ska']
# 290 ['Choir', 'Chant', 'Music', 'A capella']
# 291 ['Music', 'Christmas music']
# 292 ['Music', 'Pulse']
# 293 ['Music', 'Rhythm and blues', 'Funk']
# 294 ['Rapping', 'Music']
# 295 ['Choir', 'Music', 'Flamenco', 'Music of Asia']
# 296 ['Music', 'Funk']
# 297 ['Rattle', 'Music']
# 298 ['Music', 'Happy music']
# 299 ['Speech', 'Music', 'Electronic tuner']
# 300 ['Music', 'Electric guitar', 'Effects unit', 'Echo', 'Distortion']
# 301 ['Music', 'Skateboard']
# 302 ['Music', 'Buzzer', 'Tick']
# 303 ['Music', 'Maraca']
# 304 ['Music', 'Ukulele']
# 305 ['Singing', 'Music', 'Swing music', 'Independent music', 'Song']
# 306 ['Speech', 'Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Effects unit', 'Chorus effect']
# 307 ['Speech', 'Music', 'Traditional music']
# 308 ['Music', 'Musical instrument', 'Percussion', 'Marimba, xylophone', 'Steelpan']
# 309 ['Music', 'Electronic music', 'Dubstep']
# 310 ['Speech', 'Music', 'Boom']
# 311 ['Music', 'Musical instrument', 'Bass guitar', 'Reverberation']
# 312 ['Pig', 'Music']
# 313 ['Music', 'Classical music', 'Opera', 'Traditional music']
# 314 ['Music', 'Electronic music', 'Dubstep', 'Drum and bass']
# 315 ['Speech', 'Choir', 'Male singing', 'Music']
# 316 ['Keyboard (musical)', 'Organ', 'Hammond organ']
# 317 ['Music', 'Vibraphone', 'Inside, large room or hall']
# 318 ['Speech', 'Singing', 'Music', 'Maraca', 'Song']
# 319 ['Music', 'Sampler', 'Drum machine', 'Drum and bass', 'Electronica']
# 320 ['Mantra', 'Music']
# 321 ['Speech', 'Music', 'Fusillade']
# 322 ['Hiccup', 'Music', 'Boing']
# 323 ['Music', 'Opera']
# 324 ['Speech', 'Music', 'Air horn, truck horn']
# 325 ['Speech', 'Music', 'Beep, bleep']
# 326 ['Music', 'Soul music', 'Reggae']
# 327 ['Female singing', 'Child singing', 'Synthetic singing', 'Music']
# 328 ['Music', 'Doorbell']
# 329 ['Speech', 'Music', 'Musical instrument', 'Ukulele', 'Bowed string instrument', 'Violin, fiddle']
# 330 ['Rapping', 'Music', 'Hip hop music']
# 331 ['Music', 'Music of Asia', 'Exciting music']
# 332 ['Music', 'Rock and roll', 'Roll']
# 333 ['Speech', 'Music', 'Chink, clink']
# 334 ['Music', 'Bluegrass']
# 335 ['Speech', 'Music', 'Ping']
# 336 ['Singing', 'Music', 'Music of Asia', 'Sad music']
# 337 ['Fart', 'Music']
# 338 ['Music', 'Boing']
# 339 ['Music', 'Sitar', 'Middle Eastern music', 'Carnatic music', 'Music of Bollywood']
# 340 ['Speech', 'Music', 'Helicopter']
# 341 ['Music', 'Doorbell']
# 342 ['Music', 'Sad music', 'Tender music', 'Exciting music']
# 343 ['Animal', 'Wild animals', 'Music']
# 344 ['Speech', 'Chatter', 'Music', 'Inside, small room']
# 345 ['Music', 'Maraca']
# 346 ['Music', 'Music of Bollywood', 'Dance music']
# 347 ['Keyboard (musical)', 'Piano', 'Singing bowl']
# 348 ['Speech', 'Singing', 'Chatter', 'Music']
# 349 ['Speech', 'Throat clearing', 'Music']
# 350 ['Speech', 'Shout', 'Music']
# 351 ['Music', 'Heavy metal', 'Grunge', 'Progressive rock']
# 352 ['Music', 'Bouncing']
# 353 ['Music', 'Music of Latin America']
# 354 ['Music', 'Rock music', 'Funk', 'Ska']
# 355 ['Burping, eructation', 'Music']
# 356 ['Music', 'Explosion', 'Eruption']
# 357 ['Music', 'Skateboard']
# 358 ['Bellow', 'Whoop', 'Music', 'Burst, pop']
# 359 ['Music', 'Crack']
# 360 ['Speech', 'Shout', 'Music']
# 361 ['Music', 'Musical instrument', 'Guitar', 'Tapping (guitar technique)']
# 362 ['Music', 'Orchestra', 'Swing music', 'Music of Latin America', 'Salsa music']
# 363 ['Music', 'Swing music']
# 364 ['Keyboard (musical)', 'Piano', 'Electric piano']
# 365 ['Singing', 'Music', 'Steelpan']
# 366 ['Music', 'Foghorn']
# 367 ['Speech', 'Music', 'Electronica', 'Zipper (clothing)']
# 368 ['Music', 'Rattle (instrument)']
# 369 ['Music', 'Folk music']
# 370 ['Speech', 'Music', 'Rumble']
# 371 ['Music', 'Scratch']
# 372 ['Music', 'Vocal music', 'A capella', 'Lullaby']
# 373 ['Rapping', 'Music', 'Reggae']
# 374 ['Music', 'Rock and roll', 'Blues']
# 375 ['Music', 'Musical instrument', 'Flamenco']
# 376 ['Male speech, man speaking', 'Male singing', 'Music', 'Soul music']
# 377 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Effects unit', 'Chorus effect', 'Distortion']
# 378 ['Speech', 'Giggle', 'Music']
# 379 ['Mantra', 'Carnatic music', 'Song']
# 380 ['Child singing', 'Music']
# 381 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Banjo', 'Bluegrass', 'Blues']
# 382 ['Music', 'Sidetone']
# 383 ['Music', 'White noise']
# 384 ['Rapping', 'Music', 'Scratching (performance technique)', 'Hip hop music', 'Dubstep']
# 385 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Electronic tuner']
# 386 ['Music', 'Ambient music', 'New-age music']
# 387 ['Music', 'Music of Asia', 'Zing']
# 388 ['Music', 'Funk', 'Disco']
# 389 ['Singing', 'Choir', 'Music', 'Tambourine', 'Vocal music']
# 390 ['Singing', 'Yodeling', 'Music']
# 391 ['Speech', 'Music', 'Drum machine', 'Exciting music']
# 392 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Bass guitar', 'Effects unit', 'Distortion']
# 393 ['Music', 'Maraca', 'Beatboxing']
# 394 ['Animal', 'Domestic animals, pets', 'Dog', 'Howl', 'Music']
# 395 ['Music', 'Flamenco']
# 396 ['Music', 'Bass guitar', 'Steel guitar, slide guitar', 'Chorus effect']
# 397 ['Music', 'Music of Africa', 'Afrobeat', 'Scrape']
# 398 ['Music', 'Electronic music', 'Techno']
# 399 ['Music', 'Electric guitar', 'Bass guitar', 'Heavy metal', 'Effects unit', 'Clatter', 'Reverberation', 'Distortion']
# 400 ['Speech', 'Music', 'Telephone']
# 401 ['Music', 'Soundtrack music', 'Cacophony']
# 402 ['Music', 'Pop music', 'Soundtrack music', 'Dance music', 'Funny music']
# 403 ['Music', 'Music for children', 'Jingle (music)']
# 404 ['Oink', 'Music']
# 405 ['Speech', 'Music', 'Buzzer', 'Inside, small room']
# 406 ['Speech', 'Music', 'Thunk']
# 407 ['Speech', 'Grunt', 'Music', 'Inside, large room or hall']
# 408 ['Music', 'Drum machine', 'Rock music', 'Heavy metal', 'Grunge', 'Progressive rock']
# 409 ['Music', 'Rattle (instrument)']
# 410 ['Music', 'Musical instrument', 'Piano', 'Bowed string instrument', 'Violin, fiddle', 'Classical music']
# 411 ['Music', 'Video game music', 'Sad music']
# 412 ['Music', 'Rock and roll', 'Roll']
# 413 ['Music', 'Acoustic guitar', 'Mandolin']
# 414 ['Crying, sobbing', 'Animal', 'Music']
# 415 ['Speech', 'Domestic animals, pets', 'Howl', 'Canidae, dogs, wolves', 'Music']
# 416 ['Music', 'Wedding music']
# 417 ['Speech', 'Wheeze', 'Music']
# 418 ['Music', 'Rattle (instrument)']
# 419 ['Shout', 'Singing', 'Music', 'Inside, large room or hall', 'Inside, public space']
# 420 ['Keyboard (musical)', 'Harpsichord']
# 421 ['Music', 'Single-lens reflex camera']
# 422 ['Speech', 'Music', 'Vehicle', 'Bicycle']
# 423 ['Music', 'Sidetone']
# 424 ['Music', 'New-age music']
# 425 ['Music', 'Musical instrument', 'Didgeridoo']
# 426 ['Speech', 'Music', 'Skidding']
# 427 ['Speech', 'Bleat', 'Sheep', 'Music']
# 428 ['Music', 'Ringtone']
# 429 ['Speech', 'Music', 'Bang', 'Inside, large room or hall']
# 430 ['Rattle', 'Music']
# 431 ['Music', 'Rock music', 'Progressive rock', 'Psychedelic rock']
# 432 ['Music', 'Angry music']
# 433 ['Music', 'Bang']
# 434 ['Female singing', 'Music']
# 435 ['Speech', 'Music', 'Thump, thud', 'Basketball bounce']
# 436 ['Music', 'Vehicle', 'Ice cream truck, ice cream van']
# 437 ['Music', 'Jingle (music)']
# 438 ['Music', 'Rock music', 'Progressive rock', 'Independent music', 'Song']
# 439 ['Chant', 'Mantra', 'Music']
# 440 ['Music', 'Tap']
# 441 ['Music', 'Ukulele']
# 442 ['Keyboard (musical)', 'Piano', 'Electric piano']
# 443 ['Choir', 'Music', 'A capella', 'Lullaby']
# 444 ['Music', 'Music of Latin America', 'Salsa music', 'Funny music']
# 445 ['Music', 'Rhythm and blues', 'Reggae', 'Music of Africa', 'Afrobeat', 'Exciting music']
# 446 ['Speech', 'Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Bass guitar', 'Effects unit', 'Chorus effect']
# 447 ['Humming', 'Music', 'Song']
# 448 ['Music', 'Musical instrument', 'Drum machine', 'Sound effect']
# 449 ['Speech', 'Music', 'Tick-tock']
# 450 ['Speech', 'Throat clearing', 'Music']
# 451 ['Music', 'Boom']
# 452 ['Music', 'Background music', 'Ringtone']
# 453 ['Music', 'Synthesizer', 'Electronica', 'Cacophony']
# 454 ['Music', 'Bicycle bell']
# 455 ['Music', 'Crack']
# 456 ['Music', 'Didgeridoo']
# 457 ['Music', 'Musical instrument', 'Steelpan']
# 458 ['Male singing', 'Synthetic singing', 'Music']
# 459 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Effects unit', 'Reverberation', 'Distortion']
# 460 ['Speech', 'Music', 'Shatter', 'Outside, urban or manmade']
# 461 ['Speech', 'Music', 'Foghorn', 'Outside, rural or natural']
# 462 ['Music', 'Funk', 'Dubstep', 'Electronic dance music']
# 463 ['Speech', 'Music', 'Musical instrument', 'Didgeridoo']
# 464 ['Music', 'Bang']
# 465 ['Music', 'Rhythm and blues', 'Exciting music']
# 466 ['Music', 'Background music', 'Tender music']
# 467 ['Music', 'Single-lens reflex camera']
# 468 ['Synthetic singing', 'Music']
# 469 ['Music', 'Typewriter']
# 470 ['Speech', 'Music', 'Busy signal']
# 471 ['Speech', 'Music', 'Scary music', 'Accelerating, revving, vroom']
# 472 ['Rapping', 'Music', 'Hip hop music', 'Sound effect']
# 473 ['Music', 'Exciting music']
# 474 ['Speech', 'Music', 'Electric shaver, electric razor']
# 475 ['Music', 'Helicopter']
# 476 ['Speech', 'Music', 'Knock', 'Silence']
# 477 ['Applause', 'Music']
# 478 ['Speech', 'Music', 'Plop']
# 479 ['Music', 'Christmas music']
# 480 ['Music', 'Background music', 'Sad music']
# 481 ['Keyboard (musical)', 'Piano', 'Organ', 'Hammond organ']
# 482 ['Music', 'Bass drum', 'Maraca']
# 483 ['Rapping', 'Music', 'Exciting music']
# 484 ['Music', 'Funk']
# 485 ['Speech', 'Music', 'Thunk', 'Inside, small room']
# 486 ['Music', 'Crackle']
# 487 ['Music', 'Lullaby']
# 488 ['Keyboard (musical)', 'Harpsichord']
# 489 ['Music', 'Music of Latin America', 'Salsa music']
# 490 ['Music', 'Pulse']
# 491 ['Speech', 'Music', 'Motor vehicle (road)', 'Ice cream truck, ice cream van', 'Alarm clock']
# 492 ['Singing', 'Music', 'Opera']
# 493 ['Music', 'Country', 'Opera']
# 494 ['Music', 'Electric guitar', 'Psychedelic rock', 'Blues']
# 495 ['Speech', 'Music', 'Tap']
# 496 ['Music', 'Musical instrument', 'Classical music', 'Carnatic music']
# 497 ['Speech', 'Music', 'Timpani']
# 498 ['Music', 'Theremin']
# 499 ['Singing', 'Music', 'Steelpan']
# 500 ['Speech', 'Fart', 'Music']
# 501 ['Music', 'Musical instrument', 'Electronic music', 'Dubstep']
# 502 ['Whoop', 'Music']
# 503 ['Music', 'Middle Eastern music', 'Salsa music']
# 504 ['Music', 'Video game music']
# 505 ['Music', 'Soul music', 'Swing music']
# 506 ['Music', 'Sitar']
# 507 ['Music', 'Telephone dialing, DTMF']
# 508 ['Music', 'Scratch']
# 509 ['Speech', 'Rattle', 'Music']
# 510 ['Music', 'Scratching (performance technique)']
# 511 ['Music', 'Psychedelic rock']
# 512 ['Singing', 'Music', 'Music of Latin America', 'Christian music', 'Gospel music']
# 513 ['Speech', 'Squawk', 'Music']
# 514 ['Music', 'Musical instrument', 'Keyboard (musical)', 'Piano', 'Harmonic', 'Inside, large room or hall']
# 515 ['Music', 'Punk rock', 'Grunge']
# 516 ['Speech', 'Music', 'Inside, public space', 'Outside, urban or manmade']
# 517 ['Chant', 'Music']
# 518 ['Singing', 'Choir', 'Chant', 'Music', 'Vocal music']
# 519 ['Music', 'Tender music']
# 520 ['Speech', 'Music', 'Thunk']
# 521 ['Pant', 'Music']
# 522 ['Music', 'Swing music']
# 523 ['Music', 'Flamenco']
# 524 ['Music', 'Sad music']
# 525 ['Yip', 'Music', 'Mandolin', 'Bluegrass']
# 526 ['Music', 'Electric guitar', 'Tapping (guitar technique)']
# 527 ['Music', 'Musical instrument', 'Classical music']
# 528 ['Keyboard (musical)', 'Piano', 'Organ', 'Hammond organ']
# 529 ['Speech', 'Music', 'Scary music']
# 530 ['Music', 'Skateboard']
# 531 ['Singing', 'Choir', 'Music', 'A capella', 'Song']
# 532 ['Music', 'Background music', 'Theme music', 'Sad music']
# 533 ['Speech', 'Music', 'Alarm clock']
# 534 ['Music', 'Harmonic']
# 535 ['Speech', 'Narration, monologue', 'Speech synthesizer', 'Music']
# 536 ['Speech', 'Music', 'Vehicle', 'Bicycle']
# 537 ['Music', 'Musical instrument', 'Timpani', 'Orchestra', 'Brass instrument', 'Classical music']
# 538 ['Rock music', 'Psychedelic rock']
# 539 ['Music', 'Rock music', 'Punk rock', 'Progressive rock', 'Psychedelic rock']
# 540 ['Music', 'Effects unit', 'Echo']
# 541 ['Speech', 'Music', 'Liquid', 'Fill (with liquid)']
# 542 ['Music', 'Disco', 'House music', 'Electronica', 'Electronic dance music', 'Dance music']
# 543 ['Speech', 'Music', 'Reverberation']
# 544 ['Music', 'Rattle (instrument)']
# 545 ['Speech', 'Speech synthesizer', 'Music', 'Sampler']
# 546 ['Speech', 'Music', 'Keys jangling']
# 547 ['Speech', 'Music', 'Slosh']
# 548 ['Speech', 'Children playing', 'Music']
# 549 ['Music', 'Harmonic']
# 550 ['Singing', 'Music', 'Ukulele']
# 551 ['Music', 'Zing']
# 552 ['Music', 'Techno', 'Electronica', 'Video game music']
# 553 ['Speech', 'Music', 'Disco', 'House music', 'Electronica']
# 554 ['Speech', 'Sneeze', 'Music']
# 555 ['Music', 'Electronic music', 'Electronica', 'Ambient music', 'Noise']
# 556 ['Speech', 'Music', 'Doorbell']
# 557 ['Yodeling', 'Music']
# 558 ['Male singing', 'Music']
# 559 ['Music', 'Swing music', 'Funk', 'Music of Latin America', 'Music of Africa', 'Ska']
# 560 ['Male singing', 'Synthetic singing', 'Music']
# 561 ['Applause', 'Music', 'Orchestra']
# 562 ['Singing', 'Music', 'Acoustic guitar', 'Steel guitar, slide guitar', 'Folk music']
# 563 ['Music', 'Wedding music']
# 564 ['Music', 'Boing']
# 565 ['Speech', 'Music', 'Knock']
# 566 ['Speech', 'Music', 'Boing']
# 567 ['Speech', 'Humming', 'Music', 'Inside, small room']
# 568 ['Music', 'Air horn, truck horn']
# 569 ['Speech', 'Animal', 'Domestic animals, pets', 'Dog', 'Music', 'Squeak']
# 570 ['Music', 'Musical instrument', 'Ukulele', 'Inside, small room']
# 571 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Acoustic guitar', 'Ukulele']
# 572 ['Speech', 'Finger snapping', 'Music', 'Inside, small room']
# 573 ['Speech', 'Music', 'Boom']
# 574 ['Singing', 'Music', 'Christian music', 'Gospel music', 'Song', 'Christmas music']
# 575 ['Music', 'Silence']
# 576 ['Music', 'Afrobeat']
# 577 ['Music', 'Musical instrument', 'Mandolin', 'Rattle (instrument)']
# 578 ['Music', 'Techno', 'Drum and bass', 'Trance music']
# 579 ['Female singing', 'Child singing', 'Music']
# 580 ['Music', 'Rhythm and blues', 'Music of Africa']
# 581 ['Singing', 'Music', 'Musical instrument', 'Percussion', 'Tabla', 'Classical music']
# 582 ['Music', 'Theme music', 'Video game music', 'Tick']
# 583 ['Singing', 'Music', 'Music of Latin America', 'Ska']
# 584 ['Synthetic singing', 'Music']
# 585 ['Child singing', 'Music']
# 586 ['Music', 'Jingle (music)']
# 587 ['Speech', 'Hands', 'Music']
# 588 ['Music', 'Plop']
# 589 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Acoustic guitar', 'Country', 'Flamenco']
# 590 ['Speech', 'Music', 'Inside, public space', 'Outside, urban or manmade']
# 591 ['Music', 'Drum machine', 'Rhythm and blues']
# 592 ['Music', 'Harmonic', 'Inside, large room or hall']
# 593 ['Keyboard (musical)', 'Harpsichord']
# 594 ['Music', 'Funny music']
# 595 ['Speech', 'Music', 'Television']
# 596 ['Keyboard (musical)', 'Piano', 'Electric piano']
# 597 ['Speech', 'Music', 'Boom']
# 598 ['Music', 'Gurgling']
# 599 ['Speech', 'Groan', 'Music']
# 600 ['Speech', 'Wail, moan', 'Music', 'Outside, rural or natural']
# 601 ['Male singing', 'Female singing', 'Child singing', 'Music']
# 602 ['Music', 'Outside, rural or natural', 'Pink noise']
# 603 ['Chant', 'Crowd', 'Music', 'Vocal music']
# 604 ['Speech', 'Grunt', 'Pig', 'Music']
# 605 ['Music', 'Synthesizer', 'Bicycle bell']
# 606 ['Speech', 'Groan', 'Music', 'Music of Latin America']
# 607 ['Music', 'Bluegrass', 'Folk music', 'Music of Latin America', 'Flamenco', 'Gospel music', 'Music of Bollywood']
# 608 ['Speech', 'Music', 'Telephone bell ringing']
# 609 ['Singing', 'Music', 'Rock and roll', 'Psychedelic rock', 'Swing music']
# 610 ['Music', 'Glass']
# 611 ['Music', 'Ice cream truck, ice cream van']
# 612 ['Singing', 'Music', 'Christian music', 'Song']
# 613 ['Female speech, woman speaking', 'Gargling', 'Music']
# 614 ['Speech', 'Music', 'Ping']
# 615 ['Music', 'Drip', 'Inside, small room']
# 616 ['Animal', 'Horse', 'Clip-clop', 'Music']
# 617 ['Music', 'Bicycle bell', 'Vehicle', 'Traffic noise, roadway noise', 'Bicycle']
# 618 ['Choir', 'Music', 'Tender music']
# 619 ['Humming', 'Music']
# 620 ['Heart murmur', 'Music', 'Outside, urban or manmade']
# 621 ['Music', 'Rhythm and blues', 'Zing']
# 622 ['Music', 'Rattle (instrument)', 'Music of Africa']
# 623 ['Music', 'Typing', 'Computer keyboard']
# 624 ['Quack', 'Music']
# 625 ['Speech', 'Music', 'Breaking']
# 626 ['Speech', 'Music', 'Funny music']
# 627 ['Singing', 'Humming', 'Crowd', 'Music']
# 628 ['Speech', 'Music', 'Chink, clink']
# 629 ['Speech', 'Music', 'Printer']
# 630 ['Speech', 'Music', 'Busy signal']
# 631 ['Music', 'Cash register']
# 632 ['Speech', 'Music', 'Bell']
# 633 ['Music', 'Hip hop music', 'Disco', 'House music', 'Dubstep', 'Electronic dance music', 'Trance music']
# 634 ['Speech', 'Gargling', 'Music']
# 635 ['Speech', 'Music', 'Soul music']
# 636 ['Finger snapping', 'Music']
# 637 ['Speech', 'Music', 'Waterfall', 'Splash, splatter']
# 638 ['Music', 'Rattle (instrument)', 'Folk music']
# 639 ['Music', 'Electric guitar', 'Blues']
# 640 ['Speech', 'Music', 'Echo']
# 641 ['Speech', 'Speech synthesizer', 'Music']
# 642 ['Music', 'Environmental noise']
# 643 ['Yell', 'Singing', 'Music', 'Punk rock']
# 644 ['Speech', 'Music', 'Bell']
# 645 ['Speech', 'Music', 'Boing']
# 646 ['Music', 'Classical music']
# 647 ['Music', 'Electronic music', 'Drum and bass', 'Boom']
# 648 ['Music', 'Effects unit', 'Echo']
# 649 ['Music', 'Vocal music', 'Lullaby']
# 650 ['Music', 'Heavy metal', 'Cacophony']
# 651 ['Music', 'Synthesizer', 'Squish']
# 652 ['Music', 'Afrobeat']
# 653 ['Music', 'Rock music', 'Psychedelic rock', 'Christian music', 'Song', 'Christmas music']
# 654 ['Keyboard (musical)', 'Piano', 'Electric piano']
# 655 ['Music', 'Rattle (instrument)', 'Maraca']
# 656 ['Music', 'Sad music']
# 657 ['Rapping', 'Music', 'Hip hop music', 'Rhythm and blues', 'Reggae', 'Afrobeat', 'Christian music']
# 658 ['Music', 'Musical instrument', 'Percussion', 'Marimba, xylophone', 'Vibraphone', 'Classical music']
# 659 ['Music', 'Rock and roll', 'Roll']
# 660 ['Music', 'Didgeridoo']
# 661 ['Speech', 'Music', 'Microwave oven']
# 662 ['Music', 'Musical instrument', 'Maraca', 'Accordion']
# 663 ['Music', 'Beep, bleep']
# 664 ['Singing', 'Music', 'Vocal music', 'Gospel music']
# 665 ['Speech', 'Music', 'Television']
# 666 ['Speech', 'Music', 'Bang', 'Outside, rural or natural']
# 667 ['Speech', 'Female speech, woman speaking', 'Conversation', 'Babbling', 'Music']
# 668 ['Speech', 'Music', 'Flamenco']
# 669 ['Speech', 'Music', 'Shatter']
# 670 ['Speech', 'Music', 'Ding-dong']
# 671 ['Music', 'Soundtrack music', 'Happy music']
# 672 ['Music', 'Rock and roll', 'Harmonic']
# 673 ['Speech', 'Music', 'Glass', 'Breaking']
# 674 ['Music', 'Grunge']
# 675 ['Mantra', 'Music', 'Music of Bollywood']
# 676 ['Music', 'Christian music']
# 677 ['Music', 'Zing']
# 678 ['Music', 'Background music', 'Theme music', 'Sad music']
# 679 ['Music', 'Background music', 'Cash register', 'Beep, bleep']
# 680 ['Music', 'Clock']
# 681 ['Music', 'Soul music', 'Music of Bollywood']
# 682 ['Music', 'Synthesizer', 'Sampler']
# 683 ['Music', 'Traditional music']
# 684 ['Music', 'Didgeridoo']
# 685 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Bass guitar', 'Acoustic guitar', 'Tapping (guitar technique)']
# 686 ['Music', 'Banjo', 'Bluegrass']
# 687 ['Music', 'Electronica', 'Cacophony']
# 688 ['Speech', 'Music', 'Boing', 'Inside, large room or hall']
# 689 ['Music', 'Harmonic']
# 690 ['Music', 'Bell']
# 691 ['Speech', 'Music', 'Plop']
# 692 ['Music', 'Angry music']
# 693 ['Speech', 'Music', 'Timpani']
# 694 ['Singing', 'Music', 'Ukulele']
# 695 ['Music', 'Soundtrack music', 'Video game music', 'Cacophony']
# 696 ['Music', 'Banjo']
# 697 ['Music', 'Music of Africa', 'Song', 'Funny music']
# 698 ['Shuffle', 'Music', 'House music', 'Techno', 'Electronic dance music']
# 699 ['Speech', 'Singing', 'Music', 'Rock music', 'Heavy metal', 'Punk rock', 'Progressive rock', 'Rock and roll', 'Reggae', 'Ska']
# 700 ['Choir', 'Male singing', 'Child singing', 'Music']
# 701 ['Music', 'Musical instrument', 'Timpani', 'Orchestra', 'Classical music']
# 702 ['Speech', 'Baby cry, infant cry', 'Whimper', 'Music']
# 703 ['Music', 'Plop']
# 704 ['Speech', 'Music', 'Fusillade']
# 705 ['Wedding music']
# 706 ['Music', 'Electric guitar', 'Tapping (guitar technique)', 'Distortion']
# 707 ['Music', 'Progressive rock', 'Psychedelic rock', 'Independent music']
# 708 ['Music', 'Rock music', 'Grunge', 'Background music']
# 709 ['Speech', 'Chatter', 'Music']
# 710 ['Music', 'Chorus effect']
# 711 ['Heart murmur', 'Music', 'Music of Asia']
# 712 ['Music', 'Glass', 'Shatter']
# 713 ['Music', 'Techno', 'Drum and bass', 'Trance music', 'Dance music']
# 714 ['Bellow', 'Music']
# 715 ['Music', 'Theme music', 'Exciting music', 'Scary music']
# 716 ['Speech', 'Music', 'Sonar']
# 717 ['Music', 'Heavy metal', 'Progressive rock', 'Exciting music']
# 718 ['Singing', 'Music', 'Music of Bollywood']
# 719 ['Music', 'Hip hop music', 'Rhythm and blues']
# 720 ['Music', 'Drip']
# 721 ['Singing', 'Music', 'Roll']
# 722 ['Music', 'Bicycle bell']
# 723 ['Music', 'Musical instrument', 'Percussion', 'Marimba, xylophone', 'Steelpan']
# 724 ['Neigh, whinny', 'Music']
# 725 ['Speech', 'Music', 'Water', 'Pour']
# 726 ['Singing', 'Music', 'A capella', 'Song']
# 727 ['Singing', 'Music', 'Vocal music', 'A capella', 'Gospel music']
# 728 ['Music', 'Pop music', 'Exciting music']
# 729 ['Stomach rumble', 'Music']
# 730 ['Speech', 'Music', 'Skateboard', 'Outside, urban or manmade']
# 731 ['Music', 'Country', 'Music of Africa', 'Song']
# 732 ['Speech', 'Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Acoustic guitar', 'Strum', 'Rock music', 'Progressive rock']
# 733 ['Speech', 'Child speech, kid speaking', 'Children playing', 'Music', 'Inside, large room or hall']
# 734 ['Music', 'Spray']
# 735 ['Speech', 'Music', 'Harmonic']
# 736 ['Music', 'Angry music']
# 737 ['Music', 'Ambient music']
# 738 ['Speech', 'Music', 'Radio']
# 739 ['Music', 'Background music']
# 740 ['Music', 'Vibraphone']
# 741 ['Music', 'Theremin']
# 742 ['Music', 'Musical instrument', 'Didgeridoo']
# 743 ['Speech', 'Buzz', 'Music']
# 744 ['Music', 'Harmonic', 'Inside, large room or hall']
# 745 ['Music', 'Musical instrument', 'Guitar', 'Electric guitar', 'Effects unit', 'Chorus effect', 'Reverberation', 'Distortion']
# 746 ['Music', 'Musical instrument', 'Guitar', 'Drum machine']
# 747 ['Music', 'Timpani', 'Music of Asia']
# 748 ['Music', 'Scary music']
# 749 ['Music', 'Guitar', 'Reverberation']
# 750 ['Music', 'Ice cream truck, ice cream van']
# 751 ['Speech', 'Female speech, woman speaking', 'Chuckle, chortle', 'Sneeze', 'Music']
# 752 ['Male singing', 'Music', 'Guitar', 'Acoustic guitar']
# 753 ['Music', 'Scratching (performance technique)', 'Scratch']
# 754 ['Speech', 'Hiccup', 'Music']
# 755 ['Keyboard (musical)', 'Harpsichord']
# 756 ['Music', 'Clock']
# 757 ['Speech', 'Music', 'Cupboard open or close']
# 758 ['Music', 'Musical instrument', 'Guitar', 'Electric guitar', 'Steel guitar, slide guitar', 'Echo']
# 759 ['Speech', 'Music', 'Slosh']
# 760 ['Rapping', 'Music', 'Hip hop music']
# 761 ['Music', 'Musical instrument', 'Steelpan']
# 762 ['Speech', 'Music', 'Shuffling cards']
# 763 ['Whoop', 'Music']
# 764 ['Music', 'Rattle (instrument)']
# 765 ['Speech', 'Music', 'Ukulele', 'Bagpipes']
# 766 ['Music', 'Zipper (clothing)']
# 767 ['Music', 'Music of Latin America', 'Wedding music']
# 768 ['Music', 'Scratching (performance technique)', 'Electronic music']
# 769 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Synthesizer']
# 770 ['Applause', 'Music']
# 771 ['Speech', 'Music', 'Cash register']
# 772 ['Speech', 'Music', 'Boom']
# 773 ['Music', 'Boom']
# 774 ['Shout', 'Singing', 'Music', 'Inside, public space']
# 775 ['Speech', 'Music', 'Smoke detector, smoke alarm']
# 776 ['Music', 'Rock and roll', 'Roll']
# 777 ['Speech', 'Child speech, kid speaking', 'Children playing', 'Music']
# 778 ['Choir', 'Mantra', 'Music']
# 779 ['Music', 'Musical instrument', 'Steel guitar, slide guitar', 'Tapping (guitar technique)', 'Effects unit', 'Distortion']
# 780 ['Music', 'Theremin']
# 781 ['Music', 'Sitar']
# 782 ['Speech', 'Yell', 'Music']
# 783 ['Singing', 'Music', 'Sitar']
# 784 ['Music', 'Musical instrument', 'Keyboard (musical)', 'Synthesizer']
# 785 ['Music', 'Techno', 'Electronica', 'Trance music']
# 786 ['Humming', 'Music']
# 787 ['Music', 'Zing', 'Inside, small room']
# 788 ['Music', 'Musical instrument', 'Guitar', 'Psychedelic rock']
# 789 ['Music', 'Sampler', 'Scratching (performance technique)', 'Scratch']
# 790 ['Gasp', 'Music']
# 791 ['Speech', 'Chewing, mastication', 'Music']
# 792 ['Music', 'Musical instrument', 'Orchestra', 'Brass instrument', 'Trumpet', 'Classical music', 'Foghorn']
# 793 ['Keyboard (musical)', 'Organ', 'Hammond organ', 'Harpsichord']
# 794 ['Speech', 'Music', 'Burst, pop']
# 795 ['Musical instrument', 'Grunge']
# 796 ['Cough', 'Music']
# 797 ['Speech', 'Music', 'Maraca']
# 798 ['Music', 'Drum and bass', 'Electronic dance music', 'Zing']
# 799 ['Music', 'Tire squeal', 'Truck', 'Idling']
# 800 ['Speech', 'Music', 'Rock and roll', 'Roll']
# 801 ['Music', 'Tambourine']
# 802 ['Psychedelic rock', 'Middle Eastern music']
# 803 ['Rapping', 'Music', 'Hip hop music', 'Music of Africa']
# 804 ['Music', 'Vibraphone']
# 805 ['Speech', 'Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Acoustic guitar', 'Electronic tuner', 'Inside, small room']
# 806 ['Music', 'Harmonic']
# 807 ['Music', 'Bass guitar']
# 808 ['Quack', 'Music']
# 809 ['Singing', 'Music', 'A capella']
# 810 ['Music', 'Jazz']
# 811 ['Keyboard (musical)', 'Harpsichord', 'Bowed string instrument', 'Violin, fiddle']
# 812 ['Music', 'Scratch']
# 813 ['Music', 'Thunk', 'Inside, small room']
# 814 ['Music', 'Acoustic guitar', 'Banjo', 'Mandolin', 'Flamenco']
# 815 ['Speech', 'Music', 'Burst, pop']
# 816 ['Music', 'Pop music', 'Funk', 'Ska', 'Exciting music']
# 817 ['Speech', 'Male singing', 'Music']
# 818 ['Speech', 'Male singing', 'Music']
# 819 ['Music', 'Musical instrument', 'Steelpan']
# 820 ['Music', 'Banjo', 'Bluegrass']
# 821 ['Music', 'Classical music', 'Opera']
# 822 ['Music', 'Vibraphone']
# 823 ['Music', 'Ukulele']
# 824 ['Music', 'Afrobeat']
# 825 ['Speech', 'Music', 'Funny music']
# 826 ['Music', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Acoustic guitar', 'Steel guitar, slide guitar', 'Strum']
# 827 ['Music', 'Soundtrack music', 'Video game music', 'Funny music', 'Exciting music']
# 828 ['Music', 'Toothbrush']
# 829 ['Music', 'Musical instrument', 'Harmonic']
# 830 ['Speech', 'Music', 'Techno', 'Drum and bass']
# 831 ['Synthetic singing', 'Music']
# 832 ['Music', 'Boom']
# 833 ['Music', 'Knock']
# 834 ['Singing', 'Music', 'Gospel music', 'Wedding music']
# 835 ['Speech', 'Music', 'Beep, bleep']
# 836 ['Music', 'Music of Asia', 'Carnatic music']
# 837 ['Speech', 'Music', 'Sitar']
# 838 ['Music', 'Blues']
# 839 ['Music', 'Slam', 'Inside, small room', 'Outside, urban or manmade']
# 840 ['Music', 'Soul music', 'Reggae']
# 841 ['Music', 'Drum and bass', 'Ambient music', 'New-age music']
# 842 ['Speech', 'Music', 'Ice cream truck, ice cream van']
# 843 ['Music', 'Guitar', 'Electric guitar', 'Effects unit', 'Reverberation', 'Distortion']
# 844 ['Sneeze', 'Music']
# 845 ['Music', 'Background music', 'Funny music']
# 846 ['Music', 'Maraca']
# 847 ['Music', 'Theremin']
# 848 ['Music', 'Musical instrument', 'Plucked string instrument', 'Acoustic guitar', 'Steel guitar, slide guitar', 'Mandolin']
# 849 ['Music', 'Folk music']
# 850 ['Music', 'Guitar', 'Electric guitar', 'Wedding music', 'Distortion']
# 851 ['Music', 'Musical instrument', 'Percussion', 'Drum', 'Timpani']
# 852 ['Music', 'Country', 'Tender music']
# 853 ['Animal', 'Clip-clop', 'Neigh, whinny', 'Music']
# 854 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Effects unit', 'Reverberation', 'Distortion']
# 855 ['Singing', 'Mantra', 'Music', 'Vocal music', 'Music of Bollywood']
# 856 ['Speech', 'Music', 'Plucked string instrument', 'Guitar', 'Electric guitar', 'Effects unit', 'Reverberation']
# 857 ['Speech', 'Music', 'Breaking']
# 858 ['Music', 'Rock music', 'Heavy metal', 'Punk rock', 'Progressive rock', 'Psychedelic rock']
# 859 ['Music', 'Glass', 'Breaking']
# 860 ['Music', 'Timpani']
# 861 ['Music', 'Electronic music', 'Noise']
# 862 ['Speech', 'Music', 'Alarm clock']
# 863 ['Music', 'Music of Bollywood']
# 864 ['Singing', 'Music', 'Song', 'Jingle (music)']
# 865 ['Music', 'Explosion']
# 866 ['Speech', 'Music', 'Telephone dialing, DTMF']
# 867 ['Music', 'Bell']
# 868 ['Music', 'Angry music']
# 869 ['Music', 'Telephone bell ringing', 'Inside, small room', 'Inside, large room or hall']
# 870 ['Music', 'Reggae', 'Music of Africa']
# 871 ['Music', 'Heavy metal', 'Punk rock']
# 872 ['Music', 'Salsa music']
# 873 ['Male singing', 'Female singing', 'Music']
# 874 ['Speech', 'Clip-clop', 'Music']
# 875 ['Music', 'Classical music', 'Wedding music']
# 876 ['Music', 'Angry music']
# 877 ['Music', 'Musical instrument', 'Guitar', 'Electric guitar', 'Tapping (guitar technique)', 'Blues', 'Distortion']
# 878 ['Speech', 'Music', 'Sitar']
# 879 ['Music', 'Country']
# 880 ['Music', 'Didgeridoo']
# 881 ['Speech', 'Burping, eructation', 'Bleat', 'Music']
# 882 ['Animal', 'Pig', 'Wild animals', 'Music']
# 883 ['Music', 'Country', 'Bluegrass', 'Blues', 'Traditional music', 'Happy music']
# 884 ['Singing', 'Music', 'Pop music', 'Song', 'Burst, pop']
# 885 ['Speech', 'Shuffle', 'Music']
# 886 ['Whale vocalization', 'Music', 'Theme music']
# 887 ['Electronica', 'Ambient music', 'Ringtone']
# 888 ['Speech', 'Mouse', 'Music']
# 889 ['Music', 'Country']
# 890 ['Choir', 'Humming', 'Music']
# 891 ['Music', 'Middle Eastern music', 'Carnatic music']
# 892 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Acoustic guitar', 'Banjo']
# 893 ['Music', 'Tender music']
# 894 ['Music', 'Rustling leaves']
# 895 ['Music', 'New-age music', 'Music of Bollywood']
# 896 ['Music', 'Rock music', 'Punk rock', 'Grunge', 'Rock and roll']
# 897 ['Singing', 'Music', 'Music of Bollywood']
# 898 ['Music', 'Glass', 'Outside, urban or manmade']
# 899 ['Music', 'Sad music', 'Effects unit']
# 900 ['Music', 'Classical music', 'Opera']
# 901 ['Music', 'Sampler', 'Scratching (performance technique)', 'Beatboxing']
# 902 ['Music', 'Didgeridoo']
# 903 ['Music', 'Rock and roll', 'Roll']
# 904 ['Keyboard (musical)', 'Harpsichord']
# 905 ['Music', 'Techno', 'Dubstep', 'Electronic dance music', 'Harmonic']
# 906 ['Speech', 'Music', 'Door', 'Slam', 'Tap']
# 907 ['Speech', 'Music', 'Didgeridoo']
# 908 ['Music', 'Electronica', 'Scary music']
# 909 ['Music', 'Percussion', 'Drum', 'Pulse']
# 910 ['Music', 'Eruption']
# 911 ['Applause', 'Music']
# 912 ['Buzz', 'Music', 'Dubstep', 'Drum and bass']
# 913 ['Music', 'Tambourine']
# 914 ['Singing', 'Music', 'Folk music', 'Music of Africa']
# 915 ['Speech', 'Music', 'Bicycle bell']
# 916 ['Music', 'Jazz']
# 917 ['Music', 'New-age music', 'Lullaby']
# 918 ['Christian music']
# 919 ['Music', 'Rhythm and blues', 'Funk']
# 920 ['Music', 'Pop music', 'Pulse']
# 921 ['Speech', 'Music', 'Ping']
# 922 ['Music', 'Breaking']
# 923 ['Music', 'Soul music', 'Funk', 'Ska']
# 924 ['Music', 'Soul music', 'Squish']
# 925 ['Music', 'Traditional music']
# 926 ['Speech', 'Music', 'Basketball bounce']
# 927 ['Speech', 'Music', 'Bicycle bell', 'Music for children']
# 928 ['Singing', 'Music', 'Scratching (performance technique)', 'Pop music', 'Music of Asia', 'Song']
# 929 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Opera']
# 930 ['Music', 'Gospel music', 'Tender music']
# 931 ['Singing', 'Music', 'Mandolin', 'Ukulele']
# 932 ['Music', 'Pop music', 'Skateboard']
# 933 ['Music', 'Grunge', 'Independent music']
# 934 ['Music', 'Musical instrument', 'Percussion', 'Vibraphone']
# 935 ['Music', 'Reggae', 'Electronica']
# 936 ['Speech', 'Babbling', 'Music']
# 937 ['Speech', 'Music', 'Breaking', 'Inside, large room or hall']
# 938 ['Singing', 'Music', 'Mandolin', 'Country', 'Ska', 'Song']
# 939 ['Choir', 'Chant', 'Mantra', 'Music', 'A capella']
# 940 ['Male speech, man speaking', 'Music', 'Rhythm and blues', 'Disco']
# 941 ['Choir', 'Music', 'Christmas music']
# 942 ['Speech', 'Shout', 'Music']
# 943 ['Neigh, whinny', 'Music']
# 944 ['Music', 'Reggae', 'Disco', 'Music of Africa', 'Afrobeat']
# 945 ['Speech', 'Groan', 'Music']
# 946 ['Music', 'Electronic tuner']
# 947 ['Speech', 'Music', 'Television']
# 948 ['Music', 'Scratching (performance technique)', 'Beatboxing']
# 949 ['Singing', 'Music', 'Pop music', 'Hip hop music', 'Rhythm and blues', 'Reggae', 'Song']
# 950 ['Music', 'Water', 'Explosion', 'Boom']
# 951 ['Music', 'Drum machine', 'Drum and bass']
# 952 ['Music', 'Techno', 'Drum and bass', 'Electronica']
# 953 ['Music', 'Sad music']
# 954 ['Music', 'Squeak']
# 955 ['Singing', 'Yodeling', 'Music', 'Vocal music', 'Song']
# 956 ['Music', 'Swing music', 'Funk', 'Music for children']
# 957 ['Keyboard (musical)', 'Piano', 'Electric piano']
# 958 ['Music', 'Sitar', 'Carnatic music']
# 959 ['Music', 'Air horn, truck horn']
# 960 ['Music', 'Electronic music', 'Drum and bass', 'Pulse']
# 961 ['Music', 'Rumble', 'Inside, small room']
# 962 ['Music', 'Synthesizer', 'Sampler', 'Scratching (performance technique)', 'Scratch']
# 963 ['Singing', 'Male singing', 'Music']
# 964 ['Synthetic singing', 'Music']
# 965 ['Music', 'Ambient music', 'Video game music']
# 966 ['Music', 'Middle Eastern music']
# 967 ['Singing', 'Music', 'Pop music', 'Christian music']
# 968 ['Speech', 'Music', 'Beep, bleep']
# 969 ['Speech', 'Music', 'Exciting music']
# 970 ['Music', 'Music of Latin America', 'Ska']
# 971 ['Speech', 'Music', 'Vehicle', 'Bicycle']
# 972 ['Music', 'Flamenco']
# 973 ['Music', 'Wedding music']
# 974 ['Music', 'Drum machine', 'Scratching (performance technique)', 'Scratch']
# 975 ['Bellow', 'Music', 'Inside, large room or hall']
# 976 ['Speech', 'Screaming', 'Music', 'Beep, bleep']
# 977 ['Fart', 'Music']
# 978 ['Speech', 'Music', 'Echo']
# 979 ['Speech', 'Howl', 'Music']
# 980 ['Music', 'Musical instrument', 'Plucked string instrument', 'Guitar', 'Reverberation']
# 981 ['Singing', 'Yodeling', 'Music', 'Song']
# 982 ['Yell', 'Music']
# 983 ['Speech', 'Baby cry, infant cry', 'Music']
# 984 ['Rapping', 'Music', 'Rhythm and blues', 'Zing']
# 985 ['Speech', 'Music', 'Spray']
# 986 ['Speech', 'Music', 'Squeak']
# 987 ['Music', 'Burst, pop']
# 988 ['Music', 'Rock music', 'Progressive rock', 'Independent music']
# 989 ['Music', 'Jackhammer']
# 990 ['Child singing', 'Music']
# 991 ['Music', 'Soundtrack music', 'Video game music']
# 992 ['Speech', 'Animal', 'Crow', 'Caw', 'Music']
# 993 ['Child speech, kid speaking', 'Singing', 'Music', 'Music for children', 'Song', 'Jingle (music)']
# 994 ['Music', 'Marimba, xylophone', 'Vibraphone']
# 995 ['Music', 'Rock music', 'Progressive rock', 'Exciting music']
# 996 ['Music', 'Rhythm and blues', 'Music of Africa', 'Afrobeat']
# 997 ['Synthetic singing', 'Music']
# 998 ['Music', 'Rhythm and blues', 'Music of Africa']
# 999 ['Music', 'Bicycle']
